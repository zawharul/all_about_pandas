# %%
import pandas as pd

# Example DataFrame with boolean values
data = {'is_active': [True, False, True, False]}
df = pd.DataFrame(data)

# Convert the boolean column to integer (True -> 1, False -> 0)
df['is_active_int'] = df['is_active'].astype(int)

print(df)
# Out:
#    is_active  is_active_int
# 0       True              1
# 1      False              0
# 2       True              1
# 3      False              0
